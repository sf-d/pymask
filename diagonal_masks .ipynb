[[63874.795967709637, 1676.8399194165586, 0.0], [63874.816326962187, 32106.563317401455, 0.0]], [[66035.097860215421, 1676.8411029797826, 0.0], [66035.118219467957, 32106.56450096468, 0.0]], [[68195.39975272119, 1676.8422865430075, 0.0], [68195.420111973726, 32106.565684527897, 0.0]], [[70355.70164522696, 1676.8434701062324, 0.0], [70355.722004479496, 32106.566868091122, 0.0]], [[72516.003537732729, 1676.8446536694569, 0.0], [72516.023896985265, 32106.568051654347, 0.0]]]

# %%
polygons = list(np_to_shapely_polygons(poly))
lines = list(np_to_shapely_lines(lin))

# %%
def polygon_substract (outlines, contour):
  
  new_count = contour
  for i in outlines:
    if i.is_valid:
      new_count = new_count.difference(i)
    else:
      print(outlines.index(i))

  return new_count

# %%
def mask_intersection (polygons=polygons, lines=lines):
    all_list = []
    for p in polygons:
        poly_list =[]
        for pp in polygons:
            if p.covers(pp) and polygons.index(p)!=polygons.index(pp):
                if p in poly_list:
                    poly_list.append(pp)
                else:
                    poly_list = list(chain([p,pp]))
            else:
                pass
        all_list.append(poly_list)
    all_list = [x for x in all_list if x!=[]]
    for i in polygons:
        if any(i in sl for sl in all_list):
            pass
        else:
            all_list.append([i])
            
    m_p = []
    for i in all_list:
        m_p.append(polygon_substract(i[1:],i[0]))


    all_points = [] 
    points = []
    for p in m_p:
        for l in lines:
            if l.crosses(p):
                multi_line = (l.difference(p))
                for i in range (len(multi_line)):
                    if i ==0:
                        
                        st_p = [multi_line[i].bounds[0], multi_line[i].bounds[3], 0]
                        e_p = [multi_line[i+1].bounds[0],multi_line[i+1].bounds[1], 0]
                        points.append([st_p, e_p]) 
                    elif i == (len(multi_line)-1):
                        pass
                    else:
                        st_p = [multi_line[i].bounds[0], multi_line[i].bounds[3], 0]
                        e_p = [multi_line[i+1].bounds[0],multi_line[i+1].bounds[1], 0]
                        points.append([st_p, e_p]) 
                        
            else:
                pass


        
        
    return points

# %%
a=mask_intersection()
print(a)
# Out:
# [[[5546.644870053773, 3411.8437501103776, 0], [5546.6486620340565, 7344.447819030976, 0]], [[7706.946762559545, 3411.8437501142375, 0], [7706.950554539037, 7344.447819030976, 0]], [[9867.248655065318, 3411.843750118097, 0], [9867.252447044017, 7344.447819030976, 0]], [[12027.550547571092, 3411.843750121957, 0], [12027.554339549, 7344.447819030975, 0]], [[14187.852440076864, 3411.8437501258168, 0], [14187.85623205398, 7344.447819030975, 0]], [[16348.154332582637, 3411.843750129676, 0], [16348.155756175905, 3804.5712392227288, 0]], [[16348.155756175905, 4814.571239222729, 0], [16348.158631805361, 8102.597835881369, 0]], [[18508.45622508841, 3411.843750133536, 0], [18508.46079477434, 8506.843750149896, 0]], [[20668.758117594185, 3411.8437501373955, 0], [20668.762687279323, 8506.843750149896, 0]], [[22829.060010099955, 3411.8437501412554, 0], [22829.06123650104, 3509.843750163578, 0]], [[22829.06123650104, 5309.843750089945, 0], [22829.064579784303, 8506.843750149896, 0]], [[27149.663795
# ...
